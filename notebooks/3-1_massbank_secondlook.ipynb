# %%
#%reset
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np
from pylab import *
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
cmap = cm.get_cmap('BrBG_r', 8)
for i in range(cmap.N):
    rgba = cmap(i)
    # rgb2hex accepts rgb or rgba
    print(matplotlib.colors.rgb2hex(rgba))
    from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# #003c30
# #177b73
# #75c5ba
# #d4edea
# #f6ecd1
# #dab972
# #a26619
# #543005

# %%
df2 = pd.read_csv("../data/massbank-data/MolFps_truevspred_heatmap_data_20221201.csv")

# %%
df2.head(3)
# Out:
#     OB1   OB2   OB3   OB5   OB6  OB19  OB22  OB24  OB26  OB27  ...  \
# 0  True  True  True  True  True  True  True  True  True  True  ...
# 1  True  True  True  True  True  True  True  True  True  True  ...
# 2  True  True  True  True  True  True  True  True  True  True  ...
#
#    [CH1]([CH1][CH1]([CH2][CH1]-1~[#8])~[#8])[OH0]-1  \
# 0                                              True
# 1                                              True
# 2                                              True
#
#    C(C(Cc(:c:n:c:1:c:c:c:2):c:1:3)~[#7])c:2:3  c(:c:s:c:1~[#7]):n:1  \
# 0                                        True                  True
# 1                                        True                  True
# 2                                        True                  True
#
#    c(:c:o:c(:c:1)~[#8]):c:1~[#8]  n(:c(:c:c:c:c:1):c:1:c(:c:2)~[#8]):c:2~[#8]  \
# 0                           True                                         True
# ...

# %%
plt.figure(figsize=(16,6))
sns.set()
rdgn = sns.diverging_palette(h_neg=130, h_pos=10, s=99, l=55, sep=3,as_cmap=True)
cmap = sns.cm.rocket_r
yticks = df2.dtxsid
df3 = df2.drop(['dtxsid'], axis=1)
keptticks = yticks[::int(len(yticks)/20)]
yticks = ['' for y in yticks]
yticks[::int(len(yticks)/20)] = keptticks
xticks = df3.columns
keptticks = xticks[::int(len(xticks)/20)]
xticks = ['' for y in xticks]
xticks[::int(len(xticks)/20)] = keptticks
ax = sns.heatmap(df3, cmap = "gray", cbar=False)
# , yticklabels=False, xticklabels=False
for _, spine in ax.spines.items():spine.set_visible(True)
ax.set(xlabel='Fingerprint bits', ylabel='MassBank chemicals (#index)')
plt.savefig('../plots/massbank/MolFps_truevspred_heatmap2.png', bbox_inches = 'tight')
plt.show()
# Out:
# [Text(0.5, 30.5, 'Fingerprint bits'),
#  Text(120.5, 0.5, 'MassBank chemicals (#index)')]

# %%
df3.shape[0]
# Out:
# 2642
